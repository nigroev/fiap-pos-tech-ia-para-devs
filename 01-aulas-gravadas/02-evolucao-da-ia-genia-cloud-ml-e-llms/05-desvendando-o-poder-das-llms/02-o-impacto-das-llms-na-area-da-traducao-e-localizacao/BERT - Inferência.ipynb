# %%
# !pip install datasets
# !pip install -U 'accelerate==0.30.0'
# !pip install -U 'transformers==4.41.2'
# Out:
# Requirement already satisfied: datasets in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (4.8.4)
# Requirement already satisfied: filelock in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from datasets) (3.28.0)
# Requirement already satisfied: numpy>=1.17 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from datasets) (2.3.5)
# Requirement already satisfied: pyarrow>=21.0.0 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from datasets) (23.0.1)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from datasets) (0.4.1)
# Requirement already satisfied: pandas in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from datasets) (2.3.3)
# Requirement already satisfied: requests>=2.32.2 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from datasets) (2.32.5)
# Requirement already satisfied: httpx<1.0.0 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from datasets) (0.28.1)
# Requirement already satisfied: tqdm>=4.66.3 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from datasets) (4.67.3)
# Requirement already satisfied: xxhash in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.20 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from datasets) (0.70.19)
# Requirement already satisfied: fsspec<=2026.2.0,>=2023.1.0 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2026.2.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from datasets) (0.36.2)
# Requirement already satisfied: packaging in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from datasets) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (3.13.5)
# Requirement already satisfied: anyio in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (4.12.1)
# Requirement already satisfied: certifi in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (3.11)
# Requirement already satisfied: h11>=0.16 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.4.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.15.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (2.6.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from pandas->datasets) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from pandas->datasets) (2025.3)
# Requirement already satisfied: six>=1.5 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: accelerate==0.30.0 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (0.30.0)
# Requirement already satisfied: numpy>=1.17 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from accelerate==0.30.0) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from accelerate==0.30.0) (26.0)
# Requirement already satisfied: psutil in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from accelerate==0.30.0) (7.2.2)
# Requirement already satisfied: pyyaml in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from accelerate==0.30.0) (6.0.3)
# Requirement already satisfied: torch>=1.10.0 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from accelerate==0.30.0) (2.11.0)
# Requirement already satisfied: huggingface-hub in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from accelerate==0.30.0) (0.36.2)
# Requirement already satisfied: safetensors>=0.3.1 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from accelerate==0.30.0) (0.7.0)
# Requirement already satisfied: filelock in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from torch>=1.10.0->accelerate==0.30.0) (3.28.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from torch>=1.10.0->accelerate==0.30.0) (4.15.0)
# Requirement already satisfied: setuptools<82 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from torch>=1.10.0->accelerate==0.30.0) (79.0.1)
# Requirement already satisfied: sympy>=1.13.3 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from torch>=1.10.0->accelerate==0.30.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from torch>=1.10.0->accelerate==0.30.0) (3.6.1)
# Requirement already satisfied: jinja2 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from torch>=1.10.0->accelerate==0.30.0) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from torch>=1.10.0->accelerate==0.30.0) (2026.2.0)
# Requirement already satisfied: cuda-toolkit==13.0.2 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.10.0->accelerate==0.30.0) (13.0.2)
# Requirement already satisfied: cuda-bindings<14,>=13.0.3 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from torch>=1.10.0->accelerate==0.30.0) (13.2.0)
# Requirement already satisfied: nvidia-cudnn-cu13==9.19.0.56 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from torch>=1.10.0->accelerate==0.30.0) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu13==0.8.0 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from torch>=1.10.0->accelerate==0.30.0) (0.8.0)
# Requirement already satisfied: nvidia-nccl-cu13==2.28.9 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from torch>=1.10.0->accelerate==0.30.0) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu13==3.4.5 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from torch>=1.10.0->accelerate==0.30.0) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from torch>=1.10.0->accelerate==0.30.0) (3.6.0)
# Requirement already satisfied: nvidia-cublas==13.1.0.3.* in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.10.0->accelerate==0.30.0) (13.1.0.3)
# Requirement already satisfied: nvidia-cuda-runtime==13.0.96.* in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.10.0->accelerate==0.30.0) (13.0.96)
# Requirement already satisfied: nvidia-cufft==12.0.0.61.* in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.10.0->accelerate==0.30.0) (12.0.0.61)
# Requirement already satisfied: nvidia-cufile==1.15.1.6.* in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.10.0->accelerate==0.30.0) (1.15.1.6)
# Requirement already satisfied: nvidia-cuda-cupti==13.0.85.* in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.10.0->accelerate==0.30.0) (13.0.85)
# Requirement already satisfied: nvidia-curand==10.4.0.35.* in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.10.0->accelerate==0.30.0) (10.4.0.35)
# Requirement already satisfied: nvidia-cusolver==12.0.4.66.* in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.10.0->accelerate==0.30.0) (12.0.4.66)
# Requirement already satisfied: nvidia-cusparse==12.6.3.3.* in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.10.0->accelerate==0.30.0) (12.6.3.3)
# Requirement already satisfied: nvidia-nvjitlink==13.0.88.* in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.10.0->accelerate==0.30.0) (13.0.88)
# Requirement already satisfied: nvidia-cuda-nvrtc==13.0.88.* in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.10.0->accelerate==0.30.0) (13.0.88)
# Requirement already satisfied: nvidia-nvtx==13.0.85.* in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.10.0->accelerate==0.30.0) (13.0.85)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from cuda-bindings<14,>=13.0.3->torch>=1.10.0->accelerate==0.30.0) (1.5.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=1.10.0->accelerate==0.30.0) (1.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from huggingface-hub->accelerate==0.30.0) (1.4.3)
# Requirement already satisfied: requests in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from huggingface-hub->accelerate==0.30.0) (2.32.5)
# Requirement already satisfied: tqdm>=4.42.1 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from huggingface-hub->accelerate==0.30.0) (4.67.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from jinja2->torch>=1.10.0->accelerate==0.30.0) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from requests->huggingface-hub->accelerate==0.30.0) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from requests->huggingface-hub->accelerate==0.30.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from requests->huggingface-hub->accelerate==0.30.0) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from requests->huggingface-hub->accelerate==0.30.0) (2026.2.25)
# Requirement already satisfied: transformers==4.41.2 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (4.41.2)
# Requirement already satisfied: filelock in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from transformers==4.41.2) (3.28.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from transformers==4.41.2) (0.36.2)
# Requirement already satisfied: numpy>=1.17 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from transformers==4.41.2) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from transformers==4.41.2) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from transformers==4.41.2) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from transformers==4.41.2) (2026.4.4)
# Requirement already satisfied: requests in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from transformers==4.41.2) (2.32.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from transformers==4.41.2) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from transformers==4.41.2) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from transformers==4.41.2) (4.67.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.23.0->transformers==4.41.2) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.23.0->transformers==4.41.2) (1.4.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.23.0->transformers==4.41.2) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from requests->transformers==4.41.2) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from requests->transformers==4.41.2) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from requests->transformers==4.41.2) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/paulo/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages (from requests->transformers==4.41.2) (2026.2.25)

# %%
from transformers import BertTokenizer, EncoderDecoderModel

# Carregar o tokenizer e o modelo treinado
model_name = 'bert-base-multilingual-cased'
tokenizer = BertTokenizer.from_pretrained("./drive/MyDrive/FIAP/LLMs/Aula 2/bert-tokenizer-translation-en-pt-v3")
model = EncoderDecoderModel.from_pretrained('./drive/MyDrive/FIAP/LLMs/Aula 2/bert-translation-en-pt-v3')

# Definir o decoder_start_token_id e pad_token_id
model.config.decoder_start_token_id = tokenizer.cls_token_id
model.config.pad_token_id = tokenizer.pad_token_id
model.config.bos_token_id = tokenizer.cls_token_id
model.config.eos_token_id = tokenizer.sep_token_id
# Out:
# ---------------------------------------------------------------------------
# HFValidationError                         Traceback (most recent call last)
# File ~/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages/transformers/utils/hub.py:399, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     397 try:
#     398     # Load from URL or cache if already cached
# --> 399     resolved_file = hf_hub_download(
#     400         path_or_repo_id,
#     401         filename,
#     402         subfolder=None if len(subfolder) == 0 else subfolder,
#     403         repo_type=repo_type,
#     404         revision=revision,
#     405         cache_dir=cache_dir,
#     406         user_agent=user_agent,
#     407         force_download=force_download,
#     408         proxies=proxies,
#     409         resume_download=resume_download,
#     410         token=token,
#     411         local_files_only=local_files_only,
#     412     )
#     413 except GatedRepoError as e:
#
# File ~/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages/huggingface_hub/utils/_validators.py:106, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     105 if arg_name in ["repo_id", "from_id", "to_id"]:
# --> 106     validate_repo_id(arg_value)
#     108 elif arg_name == "token" and arg_value is not None:
#
# File ~/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages/huggingface_hub/utils/_validators.py:154, in validate_repo_id(repo_id)
#     153 if repo_id.count("/") > 1:
# --> 154     raise HFValidationError(
#     155         "Repo id must be in the form 'repo_name' or 'namespace/repo_name':"
#     156         f" '{repo_id}'. Use `repo_type` argument if needed."
#     157     )
#     159 if not REPO_ID_REGEX.match(repo_id):
#
# HFValidationError: Repo id must be in the form 'repo_name' or 'namespace/repo_name': 'drive/MyDrive/FIAP/LLMs/Aula 2/bert-tokenizer-translation-en-pt'. Use `repo_type` argument if needed.
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[4], line 5
#       3 # Carregar o tokenizer e o modelo treinado
#       4 model_name = 'bert-base-multilingual-cased'
# ----> 5 tokenizer = BertTokenizer.from_pretrained("drive/MyDrive/FIAP/LLMs/Aula 2/bert-tokenizer-translation-en-pt")
#       6 model = EncoderDecoderModel.from_pretrained('drive/MyDrive/FIAP/LLMs/Aula 2/bert-translation-en-pt-v3')
#       8 # Definir o decoder_start_token_id e pad_token_id
#
# File ~/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:2029, in PreTrainedTokenizerBase.from_pretrained(cls, pretrained_model_name_or_path, cache_dir, force_download, local_files_only, token, revision, trust_remote_code, *init_inputs, **kwargs)
#    2026 if "tokenizer_file" in vocab_files:
#    2027     # Try to get the tokenizer config to see if there are versioned tokenizer files.
#    2028     fast_tokenizer_file = FULL_TOKENIZER_FILE
# -> 2029     resolved_config_file = cached_file(
#    2030         pretrained_model_name_or_path,
#    2031         TOKENIZER_CONFIG_FILE,
#    2032         cache_dir=cache_dir,
#    2033         force_download=force_download,
#    2034         resume_download=resume_download,
#    2035         proxies=proxies,
#    2036         token=token,
#    2037         revision=revision,
#    2038         local_files_only=local_files_only,
#    2039         subfolder=subfolder,
#    2040         user_agent=user_agent,
#    2041         _raise_exceptions_for_gated_repo=False,
#    2042         _raise_exceptions_for_missing_entries=False,
#    2043         _raise_exceptions_for_connection_errors=False,
#    2044         _commit_hash=commit_hash,
#    2045     )
#    2046     commit_hash = extract_commit_hash(resolved_config_file, commit_hash)
#    2047     if resolved_config_file is not None:
#
# File ~/workspaces/fiap-pos-tech-ia-para-devs/01-aulas-gravadas/02-evolucao-da-ia-genia-cloud-ml-e-llms/07-tech-challenge/venv/lib/python3.11/site-packages/transformers/utils/hub.py:463, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     461     raise EnvironmentError(f"There was a specific connection error when trying to load {path_or_repo_id}:\n{err}")
#     462 except HFValidationError as e:
# --> 463     raise EnvironmentError(
#     464         f"Incorrect path_or_model_id: '{path_or_repo_id}'. Please provide either the path to a local folder or the repo_id of a model on the Hub."
#     465     ) from e
#     466 return resolved_file
#
# OSError: Incorrect path_or_model_id: 'drive/MyDrive/FIAP/LLMs/Aula 2/bert-tokenizer-translation-en-pt'. Please provide either the path to a local folder or the repo_id of a model on the Hub.

# %%
# Função de tradução
def translate(text, max_length=50):
    # Codifique o texto
    input_ids = tokenizer.encode(text, return_tensors="pt")

    # Defina o bos_token_id e o decoder_start_token_id
    bos_token_id = tokenizer.bos_token_id
    decoder_start_token_id = tokenizer.cls_token_id

    # Prepare as entradas para geração
    inputs = {
        "input_ids": input_ids,
        "decoder_start_token_id": decoder_start_token_id,
    }

    # Gere a saída
    outputs = model.generate(**inputs, max_length=100, num_return_sequences=1, do_sample=True, temperature=0.3)

    # Decodifique a saída gerada
    decoded_output = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return decoded_output

# %%
print(f"decoder_start_token_id: {model.config.decoder_start_token_id}", tokenizer.cls_token_id)
print(f"pad_token_id: {model.config.pad_token_id}", tokenizer.pad_token_id)
print(f"bos_token_id: {model.config.bos_token_id}", tokenizer.cls_token_id)
print(f"eos_token_id: {model.config.eos_token_id}", tokenizer.sep_token_id)
# Out:
# decoder_start_token_id: 101 101
# pad_token_id: 0 0
# bos_token_id: 101 101
# eos_token_id: 102 102

# %%
# Texto de exemplo para tradução
text = "Texto."

print(f"Texto original: {text}")
print(f"Texto traduzido: {translate(text)}")
# Out:
# Texto original: Texto.
# Texto traduzido: I've read.
